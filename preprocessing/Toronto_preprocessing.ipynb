# %%
import pandas as pd
import numpy as np
import sys
import os

# %%
df = pd.read_csv("/content/major-crime-indicators.csv")

# %%
df
# Out:
#            _id EVENT_UNIQUE_ID REPORT_DATE    OCC_DATE  REPORT_YEAR  \
# 0            1  GO-20141263217  2014-01-01  2013-12-31         2014
# 1            2  GO-20141260715  2014-01-01  2014-01-01         2014
# 2            3  GO-20141260730  2014-01-01  2014-01-01         2014
# 3            4  GO-20141260597  2014-01-01  2014-01-01         2014
# 4            5  GO-20141259762  2014-01-01  2013-12-31         2014
# ...        ...             ...         ...         ...          ...
# 420195  420196  GO-20242816627  2024-12-31  2024-12-24         2024
# 420196  420197  GO-20242815828  2024-12-31  2024-12-30         2024
# 420197  420198  GO-20242814680  2024-12-31  2024-12-31         2024
# 420198  420199  GO-20242815237  2024-12-31  2024-12-31         2024
# 420199  420200  GO-20242815267  2024-12-31  2024-12-31         2024
#
#        REPORT_MONTH  REPORT_DAY  REPORT_DOY  REPORT_DOW  REPORT_HOUR  ...  \
# 0           January           1           1  Wednesday            16  ...
# 1           January           1           1  Wednesday             3  ...
# 2           January           1           1  Wednesday             3  ...
# 3           January           1           1  Wednesday             2  ...
# 4           January           1           1  Wednesday             2  ...
# ...             ...         ...         ...         ...          ...  ...
# 420195     December          31         366  Tuesday              10  ...
# 420196     December          31         366  Tuesday               7  ...
# 420197     December          31         366  Tuesday               2  ...
# 420198     December          31         366  Tuesday               4  ...
# 420199     December          31         366  Tuesday               4  ...
#
#         UCR_CODE UCR_EXT                 OFFENCE     MCI_CATEGORY HOOD_158  \
# 0           2135     210  Theft Of Motor Vehicle       Auto Theft      043
# 1           1430     100                 Assault          Assault      092
# 2           1430     100                 Assault          Assault      105
# 3           1430     100                 Assault          Assault      080
# 4           1430     100                 Assault          Assault      164
# ...          ...     ...                     ...              ...      ...
# 420195      2135     210  Theft Of Motor Vehicle       Auto Theft      033
# 420196      2135     210  Theft Of Motor Vehicle       Auto Theft      025
# 420197      1610     200       Robbery - Mugging          Robbery      168
# 420198      2120     200                     B&E  Break and Enter      032
# 420199      2120     200                     B&E  Break and Enter      081
#
#                    NEIGHBOURHOOD_158 HOOD_140  \
# 0              Victoria Village (43)      043
# 1        Corso Italia-Davenport (92)      092
# 2          Lawrence Park North (105)      105
# 3       Palmerston-Little Italy (80)      080
# 4             Wellington Place (164)      077
# ...                              ...      ...
# 420195             Clanton Park (33)      033
# 420196   Glenfield-Jane Heights (25)      025
# 420197     Downtown Yonge East (168)      075
# 420198      Englemount-Lawrence (32)      032
# 420199        Trinity-Bellwoods (81)      081
#
#                              NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 0                        Victoria Village (43) -79.306754  43.734654
# 1                  Corso Italia-Davenport (92) -79.455770  43.677775
# 2                    Lawrence Park North (105) -79.406223  43.727681
# 3                 Palmerston-Little Italy (80) -79.415594  43.654946
# 4       Waterfront Communities-The Island (77) -79.390786  43.649125
# ...                                        ...        ...        ...
# 420195                       Clanton Park (33) -79.449706  43.734062
# 420196             Glenfield-Jane Heights (25) -79.513210  43.739385
# 420197              Church-Yonge Corridor (75) -79.378304  43.656258
# 420198                Englemount-Lawrence (32) -79.433324  43.719406
# 420199                  Trinity-Bellwoods (81) -79.418846  43.644170
#
# [420200 rows x 29 columns]

# %%
columns_to_keep = [
    'OCC_YEAR',
    'NEIGHBOURHOOD_158',
    'LAT_WGS84',
    'LONG_WGS84',
    'MCI_CATEGORY'
]

# %%
start_year_threshold = 2014

# %%
initial_rows = len(df)
df.dropna(subset=['NEIGHBOURHOOD_158', 'LAT_WGS84', 'LONG_WGS84', 'OCC_YEAR'], inplace=True)
rows_after_na = len(df)
if initial_rows > rows_after_na:
    print(f"Removed {initial_rows - rows_after_na} rows with missing essential data.")
# Out:
# Removed 6426 rows with missing essential data.

# %%
len(df)
# Out:
# 413774

# %%
df['OCC_YEAR'] = pd.to_numeric(df['OCC_YEAR'], errors='coerce')
df.dropna(subset=['OCC_YEAR'], inplace=True) # Drop rows where conversion failed
df['OCC_YEAR'] = df['OCC_YEAR'].astype(int)

# %%
len(df)
# Out:
# 412318

# %%
df_filtered = df[df['OCC_YEAR'] >= start_year_threshold].copy()
print(f"Filtered dataset has {df_filtered.shape[0]} rows.")
# Out:
# Filtered dataset has 412318 rows.

# %%
df_filtered.rename(columns={
    'NEIGHBOURHOOD_158': 'Neighbourhood',
    'LAT_WGS84': 'Latitude',
    'LONG_WGS84': 'Longitude',
    'MCI_CATEGORY': 'MCI_Category',
    'OCC_YEAR': 'Year'
}, inplace=True)

# %%
columns_to_keep = ['Neighbourhood','Latitude','Longitude','MCI_Category','Year']

# %%
df_filtered = df_filtered[columns_to_keep]

# %%
df_filtered
# Out:
#                        Neighbourhood   Latitude  Longitude     MCI_Category  \
# 1        Corso Italia-Davenport (92)  43.677775 -79.455770          Assault
# 2          Lawrence Park North (105)  43.727681 -79.406223          Assault
# 3       Palmerston-Little Italy (80)  43.654946 -79.415594          Assault
# 5                   West Rouge (143)  43.780413 -79.132915          Assault
# 6                   West Rouge (143)  43.780413 -79.132915          Assault
# ...                              ...        ...        ...              ...
# 420195             Clanton Park (33)  43.734062 -79.449706       Auto Theft
# 420196   Glenfield-Jane Heights (25)  43.739385 -79.513210       Auto Theft
# 420197     Downtown Yonge East (168)  43.656258 -79.378304          Robbery
# 420198      Englemount-Lawrence (32)  43.719406 -79.433324  Break and Enter
# 420199        Trinity-Bellwoods (81)  43.644170 -79.418846  Break and Enter
#
#         Year
# 1       2014
# 2       2014
# 3       2014
# 5       2014
# 6       2014
# ...      ...
# 420195  2024
# 420196  2024
# 420197  2024
# 420198  2024
# 420199  2024
#
# [412318 rows x 5 columns]

# %%
output_csv_path = '/content/major-crime-indicators.csv'

# %%
df_filtered.to_csv(output_csv_path, index=False)

# %%
if os.path.exists(output_csv_path):
    file_size_bytes = os.path.getsize(output_csv_path)
    file_size_mb = file_size_bytes / (1024 * 1024)
    print(f"Output file size: {file_size_mb:.2f} MB")
# Out:
# Output file size: 29.58 MB

# %%
df = df_filtered

# %%
df['MCI_Category'].unique()
# Out:
# array(['Assault', 'Break and Enter', 'Theft Over', 'Robbery',
#        'Auto Theft'], dtype=object)

# %%
yearly_counts = df.groupby("Year", as_index=False).size()

# %%
yearly_counts
# Out:
#     Year   size
# 0   2014  32009
# 1   2015  32631
# 2   2016  33157
# 3   2017  34979
# 4   2018  36982
# 5   2019  39252
# 6   2020  34731
# 7   2021  34338
# 8   2022  40976
# 9   2023  48523
# 10  2024  44740

# %%
df["Neighbourhood"] = df["Neighbourhood"].str.replace(r"\s*\(\d+\)", "", regex=True)

# %%
df
# Out:
#                   Neighbourhood   Latitude  Longitude     MCI_Category  Year
# 1        Corso Italia-Davenport  43.677775 -79.455770          Assault  2014
# 2           Lawrence Park North  43.727681 -79.406223          Assault  2014
# 3       Palmerston-Little Italy  43.654946 -79.415594          Assault  2014
# 5                    West Rouge  43.780413 -79.132915          Assault  2014
# 6                    West Rouge  43.780413 -79.132915          Assault  2014
# ...                         ...        ...        ...              ...   ...
# 420195             Clanton Park  43.734062 -79.449706       Auto Theft  2024
# 420196   Glenfield-Jane Heights  43.739385 -79.513210       Auto Theft  2024
# 420197      Downtown Yonge East  43.656258 -79.378304          Robbery  2024
# 420198      Englemount-Lawrence  43.719406 -79.433324  Break and Enter  2024
# 420199        Trinity-Bellwoods  43.644170 -79.418846  Break and Enter  2024
#
# [412318 rows x 5 columns]

# %%
mci_map = {cat: i+1 for i, cat in enumerate(sorted(df["MCI_Category"].unique()))}
df["MCI_Category_ID"] = df["MCI_Category"].map(mci_map)

# %%
mci_map
# Out:
# {'Assault': 1,
#  'Auto Theft': 2,
#  'Break and Enter': 3,
#  'Robbery': 4,
#  'Theft Over': 5}

# %%
mci_map_df = pd.DataFrame(list(mci_map.items()), columns=["MCI_Category", "ID"])
mci_map_df.to_csv("/content/mci_map.csv", index=False)

# %%
mci_map_df
# Out:
#       MCI_Category  ID
# 0          Assault   1
# 1       Auto Theft   2
# 2  Break and Enter   3
# 3          Robbery   4
# 4       Theft Over   5

# %%
neigh_map = {name: i+1 for i, name in enumerate(sorted(df["Neighbourhood"].unique()))}

# %%
neigh_map
# Out:
# {'Agincourt North': 1,
#  'Agincourt South-Malvern West': 2,
#  'Alderwood': 3,
#  'Annex': 4,
#  'Avondale': 5,
#  'Banbury-Don Mills': 6,
#  'Bathurst Manor': 7,
#  'Bay-Cloverhill': 8,
#  'Bayview Village': 9,
#  'Bayview Woods-Steeles': 10,
#  'Bedford Park-Nortown': 11,
#  'Beechborough-Greenbrook': 12,
#  'Bendale South': 13,
#  'Bendale-Glen Andrew': 14,
#  'Birchcliffe-Cliffside': 15,
#  'Black Creek': 16,
#  'Blake-Jones': 17,
#  'Briar Hill-Belgravia': 18,
#  'Bridle Path-Sunnybrook-York Mills': 19,
#  'Broadview North': 20,
#  'Brookhaven-Amesbury': 21,
#  'Cabbagetown-South St.James Town': 22,
#  'Caledonia-Fairbank': 23,
#  'Casa Loma': 24,
#  'Centennial Scarborough': 25,
#  'Church-Wellesley': 26,
#  'Clairlea-Birchmount': 27,
#  'Clanton Park': 28,
#  'Cliffcrest': 29,
#  'Corso Italia-Davenport': 30,
#  'Danforth': 31,
#  'Danforth East York': 32,
#  'Don Valley Village': 33,
#  'Dorset Park': 34,
#  'Dovercourt Village': 35,
#  'Downsview': 36,
#  'Downtown Yonge East': 37,
#  'Dufferin Grove': 38,
#  'East End-Danforth': 39,
#  "East L'Amoreaux": 40,
#  'East Willowdale': 41,
#  'Edenbridge-Humber Valley': 42,
#  'Eglinton East': 43,
#  'Elms-Old Rexdale': 44,
#  'Englemount-Lawrence': 45,
#  'Eringate-Centennial-West Deane': 46,
#  'Etobicoke City Centre': 47,
#  'Etobicoke West Mall': 48,
#  'Fenside-Parkwoods': 49,
#  'Flemingdon Park': 50,
#  'Forest Hill North': 51,
#  'Forest Hill South': 52,
#  'Fort York-Liberty Village': 53,
#  'Glenfield-Jane Heights': 54,
#  'Golfdale-Cedarbrae-Woburn': 55,
#  'Greenwood-Coxwell': 56,
#  'Guildwood': 57,
#  'Harbourfront-CityPlace': 58,
#  'Henry Farm': 59,
#  'High Park North': 60,
#  'High Park-Swansea': 61,
#  'Highland Creek': 62,
#  'Hillcrest Village': 63,
#  'Humber Bay Shores': 64,
#  'Humber Heights-Westmount': 65,
#  'Humber Summit': 66,
#  'Humbermede': 67,
#  'Humewood-Cedarvale': 68,
#  'Ionview': 69,
#  'Islington': 70,
#  'Junction Area': 71,
#  'Junction-Wallace Emerson': 72,
#  'Keelesdale-Eglinton West': 73,
#  'Kennedy Park': 74,
#  'Kensington-Chinatown': 75,
#  'Kingsview Village-The Westway': 76,
#  'Kingsway South': 77,
#  "L'Amoreaux West": 78,
#  'Lambton Baby Point': 79,
#  'Lansing-Westgate': 80,
#  'Lawrence Park North': 81,
#  'Lawrence Park South': 82,
#  'Leaside-Bennington': 83,
#  'Little Portugal': 84,
#  'Long Branch': 85,
#  'Malvern East': 86,
#  'Malvern West': 87,
#  'Maple Leaf': 88,
#  'Markland Wood': 89,
#  'Milliken': 90,
#  'Mimico-Queensway': 91,
#  'Morningside': 92,
#  'Morningside Heights': 93,
#  'Moss Park': 94,
#  'Mount Dennis': 95,
#  'Mount Olive-Silverstone-Jamestown': 96,
#  'Mount Pleasant East': 97,
#  'NSA': 98,
#  'New Toronto': 99,
#  'Newtonbrook East': 100,
#  'Newtonbrook West': 101,
#  'North Riverdale': 102,
#  'North St.James Town': 103,
#  'North Toronto': 104,
#  "O'Connor-Parkview": 105,
#  'Oakdale-Beverley Heights': 106,
#  'Oakridge': 107,
#  'Oakwood Village': 108,
#  'Old East York': 109,
#  'Palmerston-Little Italy': 110,
#  "Parkwoods-O'Connor Hills": 111,
#  'Pelmo Park-Humberlea': 112,
#  'Playter Estates-Danforth': 113,
#  'Pleasant View': 114,
#  'Princess-Rosethorn': 115,
#  'Regent Park': 116,
#  'Rexdale-Kipling': 117,
#  'Rockcliffe-Smythe': 118,
#  'Roncesvalles': 119,
#  'Rosedale-Moore Park': 120,
#  'Runnymede-Bloor West Village': 121,
#  'Rustic': 122,
#  'Scarborough Village': 123,
#  'South Eglinton-Davisville': 124,
#  'South Parkdale': 125,
#  'South Riverdale': 126,
#  'St Lawrence-East Bayfront-The Islands ': 127,
#  'St.Andrew-Windfields': 128,
#  'Steeles': 129,
#  'Stonegate-Queensway': 130,
#  "Tam O'Shanter-Sullivan": 131,
#  'Taylor-Massey': 132,
#  'The Beaches': 133,
#  'Thistletown-Beaumond Heights': 134,
#  'Thorncliffe Park': 135,
#  'Trinity-Bellwoods': 136,
#  'University': 137,
#  'Victoria Village': 138,
#  'Wellington Place': 139,
#  'West Hill': 140,
#  'West Humber-Clairville': 141,
#  'West Queen West': 142,
#  'West Rouge': 143,
#  'Westminster-Branson': 144,
#  'Weston': 145,
#  'Weston-Pelham Park': 146,
#  'Wexford/Maryvale': 147,
#  'Willowdale West': 148,
#  'Willowridge-Martingrove-Richview': 149,
#  'Woburn North': 150,
#  'Woodbine Corridor': 151,
#  'Woodbine-Lumsden': 152,
#  'Wychwood': 153,
#  'Yonge-Bay Corridor': 154,
#  'Yonge-Doris': 155,
#  'Yonge-Eglinton': 156,
#  'Yonge-St.Clair': 157,
#  'York University Heights': 158,
#  'Yorkdale-Glen Park': 159}

# %%
df["Neighbourhood_ID"] = df["Neighbourhood"].map(neigh_map)

# %%
neigh_map_df = pd.DataFrame(list(neigh_map.items()), columns=["Neighbourhood", "ID"])
neigh_map_df.to_csv("/content/neighbourhood_map.csv", index=False)

# %%
df
# Out:
#                   Neighbourhood   Latitude  Longitude     MCI_Category  Year  \
# 1        Corso Italia-Davenport  43.677775 -79.455770          Assault  2014
# 2           Lawrence Park North  43.727681 -79.406223          Assault  2014
# 3       Palmerston-Little Italy  43.654946 -79.415594          Assault  2014
# 5                    West Rouge  43.780413 -79.132915          Assault  2014
# 6                    West Rouge  43.780413 -79.132915          Assault  2014
# ...                         ...        ...        ...              ...   ...
# 420195             Clanton Park  43.734062 -79.449706       Auto Theft  2024
# 420196   Glenfield-Jane Heights  43.739385 -79.513210       Auto Theft  2024
# 420197      Downtown Yonge East  43.656258 -79.378304          Robbery  2024
# 420198      Englemount-Lawrence  43.719406 -79.433324  Break and Enter  2024
# 420199        Trinity-Bellwoods  43.644170 -79.418846  Break and Enter  2024
#
#         MCI_Category_ID  Neighbourhood_ID
# 1                     1                30
# 2                     1                81
# 3                     1               110
# 5                     1               143
# 6                     1               143
# ...                 ...               ...
# 420195                2                28
# 420196                2                54
# 420197                4                37
# 420198                3                45
# 420199                3               136
#
# [412318 rows x 7 columns]

# %%
mapped_df = df[[
    "Year",
    "Neighbourhood_ID",
    "MCI_Category_ID",
    "Latitude",
    "Longitude",
]]

# %%
mapped_df
# Out:
#         Year  Neighbourhood_ID  MCI_Category_ID   Latitude  Longitude
# 1       2014                30                1  43.677775 -79.455770
# 2       2014                81                1  43.727681 -79.406223
# 3       2014               110                1  43.654946 -79.415594
# 5       2014               143                1  43.780413 -79.132915
# 6       2014               143                1  43.780413 -79.132915
# ...      ...               ...              ...        ...        ...
# 420195  2024                28                2  43.734062 -79.449706
# 420196  2024                54                2  43.739385 -79.513210
# 420197  2024                37                4  43.656258 -79.378304
# 420198  2024                45                3  43.719406 -79.433324
# 420199  2024               136                3  43.644170 -79.418846
#
# [412318 rows x 5 columns]

# %%
mapped_df.to_csv(output_csv_path, index=False)

# %%
if os.path.exists(output_csv_path):
    file_size_bytes = os.path.getsize(output_csv_path)
    file_size_mb = file_size_bytes / (1024 * 1024)
    print(f"Output file size: {file_size_mb:.2f} MB")
# Out:
# Output file size: 18.59 MB

# %%
unique_latlong = mapped_df[["Latitude", "Longitude"]].drop_duplicates()

# %%
print("Unique (Latitude, Longitude) pairs:", len(unique_latlong))
# Out:
# Unique (Latitude, Longitude) pairs: 19223

# %%
unique_latlong = df[["Latitude", "Longitude"]].drop_duplicates().reset_index(drop=True)

# %%
len(unique_latlong)
# Out:
# 19223

# %%
unique_latlong["LatLong_ID"] = unique_latlong.index + 1

# %%
mapped_df = mapped_df.merge(unique_latlong, on=["Latitude", "Longitude"], how="left")

# %%
mapped_df["LatLong_ID"].isna().sum()
# Out:
# np.int64(0)

# %%
mapped_df.drop(columns=["Latitude", "Longitude"], inplace=True)

# %%
unique_latlong.to_csv("/content/latlong_id_map.csv", index=False)

# %%
mapped_df.to_csv(output_csv_path, index=False)

# %%
#now lets check all file sizes

# %%
def check_file_size(file_path:str):
  if os.path.exists(file_path):
    file_size_bytes = os.path.getsize(file_path)
    file_size_mb = file_size_bytes / (1024 * 1024)
    return file_size_mb

# %%
csv_files = [file for file in os.listdir("/content/") if file.endswith('.csv')]

for file in csv_files:
    print(file)
# Out:
# neighbourhood_map.csv
# latlong_id_map.csv
# major-crime-indicators.csv
# mci_map.csv

# %%
total_size = 0

# %%
for file in csv_files:
  total_size += check_file_size(file)
print(f"total Output file size: {total_size:.2f} MB")
# Out:
# total Output file size: 6.78 MB

# %%
#  well we finally got it under 10!

# %%
mapped_df
# Out:
#         Year  Neighbourhood_ID  MCI_Category_ID  LatLong_ID
# 0       2014                30                1           1
# 1       2014                81                1           2
# 2       2014               110                1           3
# 3       2014               143                1           4
# 4       2014               143                1           4
# ...      ...               ...              ...         ...
# 412313  2024                28                2       12192
# 412314  2024                54                2         128
# 412315  2024                37                4         269
# 412316  2024                45                3        6809
# 412317  2024               136                3         596
#
# [412318 rows x 4 columns]

# %%
unique_latlong
# Out:
#         Latitude  Longitude  LatLong_ID
# 0      43.677775 -79.455770           1
# 1      43.727681 -79.406223           2
# 2      43.654946 -79.415594           3
# 3      43.780413 -79.132915           4
# 4      43.686293 -79.486285           5
# ...          ...        ...         ...
# 19218  43.633507 -79.507854       19219
# 19219  43.781159 -79.129854       19220
# 19220  43.700742 -79.400431       19221
# 19221  43.760778 -79.418256       19222
# 19222  43.749535 -79.250405       19223
#
# [19223 rows x 3 columns]
